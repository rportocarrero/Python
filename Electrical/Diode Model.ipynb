# %%
from Diode import *

# %%
T = 273 # kelvin to celcius

# Plot the response for 3 diodes at temperatures -20, 20, and 60 C
D = Diode(10e-12,T-20,1)
D2 = Diode(10e-12,T+20,1)
D3 = Diode(10e-12,T+60,1)
plot_IV(D,0,2)
plot_IV(D2,0,2)
plot_IV(D3,0,2)
plt.legend(["-20","20","60"])
plt.show()
